# %% [markdown]
# <a href="https://colab.research.google.com/github/ralphpatrick/sales_predictions/blob/main/Project_1_Part_3_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing pandas
import pandas as pd
filename = '/content/sales_predictions (1).csv'

df = pd.read_csv(filename)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1) How many rows and columns?
#
# 2) What are the datatypes of each variable?
#
# 3) Are there duplicates? If so, drop any duplicates.
#
# 4) Identify missing values.
#
# 5) Decide on how to address the missing values and do it! (This requires your judgement, so explain your choice).
#
# 6) Confirm that there are no missing values after addressing them.
#
# 7) Find and fix any inconsistent categories of data (example: fix cat, Cat, and cats so that they are consistent)
#
# 8) For any numerical columns, obtain the summary statistics of each (min, max, mean)

# %%
#1) How many rows and columns?
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# 8523 Rows and 12 Columns

# %%
# 2) What are the datatypes of each variable?

df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# 3) Are there duplicates? If so, drop any duplicates.
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No Duplicates

# %%
# 4) Identify missing values.
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# 5. Decide on how to address the missing values and do it! (This requires your judgement, so explain your choice).
df.sample(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3456           FDV33         9.60          Regular         0.027399
# 7289           FDA25        16.50          Regular         0.068511
# 3053           NCL41          NaN          Low Fat         0.073077
# 7215           FDV21        11.50          Low Fat         0.286358
# 6475           FDC56         7.72          Low Fat         0.122016
# 3731           FDW32        18.35          Regular         0.094488
# 400            NCK31          NaN          Low Fat         0.026917
# 6579           FDP39        12.65          Low Fat         0.116203
# 2715           FDW59          NaN          Low Fat         0.036271
# 6539           NCT42          NaN          Low Fat         0.024767
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3456            Snack Foods  258.3304            OUT045
# 7289                 Canned  103.6990            OUT017
# ...

# %%
# NaN values turned into 0.00 float64
df.loc[:,'Item_Weight'].fillna(0.00, inplace=True)

# %%
df.loc[0:20,'Item_Weight']
# Out:
# 0      9.300
# 1      5.920
# 2     17.500
# 3     19.200
# 4      8.930
# 5     10.395
# 6     13.650
# 7      0.000
# 8     16.200
# 9     19.200
# 10    11.800
# 11    18.500
# 12    15.100
# 13    17.600
# 14    16.350
# 15     9.000
# 16    11.800
# 17     9.000
# 18     0.000
# 19    13.350
# 20    18.850
# Name: Item_Weight, dtype: float64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
isnamask = df['Outlet_Size'].isna()
df[isnamask]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
# NaN values turned into None object
df.loc[:,'Outlet_Size'].fillna('None', inplace=True)

# %%
#now groupby
df.groupby(['Outlet_Size','Outlet_Establishment_Year'])['Item_Outlet_Sales'].sum()
# Out:
# Outlet_Size  Outlet_Establishment_Year
# High         1987                         2.142664e+06
# Medium       1985                         3.453926e+06
#              1999                         2.183970e+06
#              2009                         1.851823e+06
# None         1998                         1.883402e+05
#              2002                         2.036725e+06
#              2007                         2.167465e+06
# Small        1985                         1.796941e+05
#              1997                         2.118395e+06
#              2004                         2.268123e+06
# Name: Item_Outlet_Sales, dtype: float64

# %%
# 6. Confirm that there are no missing values after addressing them.

df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#  7. Find and fix any inconsistent categories of data (example: fix cat, Cat, and cats so that they are consistent)
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
#change Item_Fat_Content to consistent data 1

df.loc[df['Item_Fat_Content'] == 'LF', 'Item_Fat_Content'] = 'Low Fat'

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5405
# Regular    2889
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
#change Item_Fat_Content to consistent data 2

df.loc[df['Item_Fat_Content'] == 'low fat', 'Item_Fat_Content'] = 'Low Fat'

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    2889
# reg         117
# Name: Item_Fat_Content, dtype: int64

# %%
#change Item_Fat_Content to consistent data 3

df.loc[df['Item_Fat_Content'] == 'reg', 'Item_Fat_Content'] = 'Regular'

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# 8. For any numerical columns, obtain the summary statistics of each (min, max, mean)

df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     10.650590         0.066132   140.992782                1997.831867
# std       6.431899         0.051598    62.275067                   8.371760
# min       0.000000         0.000000    31.290000                1985.000000
# 25%       6.650000         0.026989    93.826500                1987.000000
# 50%      11.000000         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# - Histogram to view the distributions of various features in your dataset.
# - Boxplot to view statistical summaries of various features in your dataset.
# - Heatmap of the correlation between features.

# %%
#creating a histogram
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Using OOP

fig, ax = plt.subplots(figsize=(15,5))

ax.hist(df['Item_Type'], bins='auto')
ax.set_xlabel("Item Type")
ax.set_ylabel('Number of Sold Products')
ax.tick_params(axis='x', labelrotation = 45)
ax.set_title('Number of Products Sold by Item Type')
# Out:
# Text(0.5, 1.0, 'Number of Products Sold by Item Type')

# %%
# Boxplot to view statistical summaries of various features in your dataset.

df.describe()
df['Item_Outlet_Sales'].sum()
# Out:
# 18591125.4104

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.boxplot(df['Item_Outlet_Sales']);
ax1.set_title("Outlet Sales")
ax1.set_ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
# Heatmap of the correlation between features.

df.corr()
# Out:
# <ipython-input-92-88e5163e20bc>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.077522  0.022859
# Item_Visibility              -0.077522         1.000000 -0.001315
# Item_MRP                      0.022859        -0.001315  1.000000
# Outlet_Establishment_Year     0.520561        -0.074834  0.005020
# Item_Outlet_Sales            -0.053222        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                 0.520561          -0.053222
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# ...

# %%
sns.heatmap(df.corr(), cmap = 'BuPu', annot = True)
# Out:
# <ipython-input-96-4ac290463ec0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap = 'BuPu', annot = True)
# <Axes: >
